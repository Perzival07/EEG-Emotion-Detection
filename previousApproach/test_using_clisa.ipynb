# %% [markdown]
# ### Imports & GPU Configuration

# %%
# ==============================================================================
# 0. Importing Dependencies
# ==============================================================================
import os
import glob
import numpy as np
import pandas as pd
import tensorflow as tf
import pywt
import datetime
import json
from typing import List, Tuple, Dict, Optional

# Keras and TensorFlow Layers for the CLISA Model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, DepthwiseConv2D, SeparableConv2D, BatchNormalization,
    AveragePooling2D, Bidirectional, LSTM, Dropout, Dense, concatenate,
    Layer, GlobalAveragePooling1D, Reshape
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TensorBoard
from tensorflow.keras.constraints import max_norm

# Scikit-learn for data splitting and class weights
try:
    from sklearn.model_selection import train_test_split
    from sklearn.utils.class_weight import compute_class_weight
    _HAVE_SKLEARN = True
except ImportError:
    _HAVE_SKLEARN = False

# ==============================================================================
# 1. GPU Memory Configuration
# ==============================================================================
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"GPU memory growth configured for {len(gpus)} device(s).")
    except RuntimeError as e:
        print(e)
# Out:
# 2025-09-22 06:11:21.488795: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU memory growth configured for 1 device(s).

# %% [markdown]
# ### Global Constants & Configuration

# %%
# ==============================================================================
# 2. Configuration and Constants
# ==============================================================================
CLASS_NAMES = [
    'happy', 'sad', 'surprised', 'satisfied',
    'protected', 'frightened', 'angry', 'unconcerned'
]

FOLDER_TO_CLASS = {
    'Happy': 'happy',
    'Sad': 'sad',
    'Surprise': 'surprised',
    'Satisfied': 'satisfied',
    'Protected': 'protected',
    'Frightened': 'frightened',
    'Angry': 'angry',
    'Unconcerned': 'unconcerned'
}

# The model from the paper was designed for 62 channels, but we can adapt it.
# We will focus on the 14 core EEG channels for a robust signal.
EEG_CHANNELS = [
    'EEG.AF3', 'EEG.F7', 'EEG.F3', 'EEG.FC5', 'EEG.T7', 'EEG.P7', 'EEG.O1',
    'EEG.O2', 'EEG.P8', 'EEG.T8', 'EEG.FC6', 'EEG.F4', 'EEG.F8', 'EEG.AF4'
]

# %% [markdown]
# ### Data Loading (Adapted for CLISA)

# %%
# ==============================================================================
# 3. Data Loading and Preprocessing Functions (Adapted for CLISA)
# ==============================================================================

# Functions: wavelet_denoise and _normalize_per_sample remain the same.

def wavelet_denoise(data, wavelet='db4', level=4):
    """Applies wavelet denoising to a 1D signal."""
    coeffs = pywt.wavedec(data, wavelet, level=level)
    sigma = np.median(np.abs(coeffs[-1] - np.median(coeffs[-1]))) / 0.6745
    threshold = sigma * np.sqrt(2 * np.log(len(data)))
    new_coeffs = coeffs.copy()
    for i in range(1, len(coeffs)):
        new_coeffs[i] = pywt.threshold(coeffs[i], value=threshold, mode='soft')
    reconstructed_signal = pywt.waverec(new_coeffs, wavelet)
    return reconstructed_signal[:len(data)]

def _read_and_denoise_csv(filepath: str) -> np.ndarray:
    """Reads a CSV and returns a (time_points, channels) array of the core EEG signals."""
    df = pd.read_csv(filepath, skiprows=1, low_memory=False)
    denoised_data = {}
    for channel in EEG_CHANNELS:
        if channel in df.columns:
            signal = df[channel].dropna().values
            denoised_data[channel] = wavelet_denoise(signal) if np.var(signal) > 0 else signal
    
    max_len = max(len(v) for v in denoised_data.values()) if denoised_data else 0
    for channel, signal in denoised_data.items():
        if len(signal) < max_len:
            padding = np.zeros(max_len - len(signal))
            denoised_data[channel] = np.concatenate([signal, padding])
            
    return pd.DataFrame(denoised_data).values.astype(np.float32)

def _ensure_shape_and_pad(raw: np.ndarray, channels: int, time_steps: int) -> np.ndarray:
    """Ensure data has shape (channels, time_steps) by padding/truncating and transposing."""
    # Transpose to (channels, time_points)
    data = raw.T
    
    if data.shape[1] > time_steps:
        data = data[:, :time_steps]
    elif data.shape[1] < time_steps:
        padding = np.zeros((channels, time_steps - data.shape[1]), dtype=data.dtype)
        data = np.concatenate([data, padding], axis=1)
    return data

def _normalize_per_sample(sample: np.ndarray) -> np.ndarray:
    """Normalize each sample."""
    mean = sample.mean()
    std = sample.std()
    return (sample - mean) / (std + 1e-8)

def load_eeg_dataset(
    data_dir: str, channels: int, time_steps: int,
    stressed_classes: Optional[List[str]] = None, test_size: float = 0.15,
    val_size: float = 0.15, random_state: int = 42, batch_size: int = 4
) -> Tuple[Dict[str, tf.data.Dataset], Dict]:
    """Load EEG dataset, preparing it for the CLISA model architecture."""
    # ... (The core logic of finding files and splitting data remains the same) ...
    if not _HAVE_SKLEARN:
        raise ImportError("Scikit-learn is required.")

    if stressed_classes is None: stressed_classes = ['frightened', 'angry']
    
    files, labels = [], []
    for folder, cls in FOLDER_TO_CLASS.items():
        cls_folder = os.path.join(data_dir, folder)
        if os.path.isdir(cls_folder):
            found = glob.glob(os.path.join(cls_folder, "*.csv"))
            files.extend(found)
            labels.extend([cls] * len(found))

    if not files: raise ValueError(f"No CSV files found in {data_dir}.")

    X_list, y_multi_idx, y_binary = [], [], []
    for fpath, cls in zip(files, labels):
        raw = _read_and_denoise_csv(fpath)
        if raw.shape[1] != channels: continue # Skip if channel count is wrong
            
        sample = _ensure_shape_and_pad(raw, channels, time_steps)
        sample = _normalize_per_sample(sample)
        # Add a final dimension for the CNN: (channels, time_points, 1)
        X_list.append(sample[..., np.newaxis].astype(np.float32)) 
        
        y_multi_idx.append(CLASS_NAMES.index(cls))
        y_binary.append(1 if cls in stressed_classes else 0)

    X = np.stack(X_list, axis=0)
    # ... (The rest of the function is the same as the last working version) ...
    y_multi_idx = np.array(y_multi_idx, dtype=np.int32)
    y_binary = np.array(y_binary, dtype=np.float32)
    y_multi_onehot = tf.keras.utils.to_categorical(y_multi_idx, num_classes=len(CLASS_NAMES))
    
    weights = compute_class_weight('balanced', classes=np.arange(len(CLASS_NAMES)), y=y_multi_idx)
    class_weights = {i: float(w) for i, w in enumerate(weights)}
    
    emotion_sample_weights = np.array([class_weights[label] for label in y_multi_idx], dtype=np.float32)
    stress_sample_weights = np.ones_like(y_binary, dtype=np.float32)
    
    indices = np.arange(len(X))
    train_indices, temp_indices = train_test_split(indices, test_size=(test_size + val_size), random_state=random_state, stratify=y_multi_idx)
    val_indices, test_indices = train_test_split(temp_indices, test_size=(test_size / (test_size + val_size)), random_state=random_state, stratify=y_multi_idx[temp_indices])

    def make_ds(inds):
        x = X[inds]
        y = {'stressed_not_stressed_output': y_binary[inds], 'emotion_class_output': y_multi_onehot[inds]}
        sw = {'stressed_not_stressed_output': stress_sample_weights[inds], 'emotion_class_output': emotion_sample_weights[inds]}
        return tf.data.Dataset.from_tensor_slices((x, y, sw)).shuffle(len(inds), seed=random_state).batch(batch_size).prefetch(tf.data.AUTOTUNE)

    datasets = {'train': make_ds(train_indices), 'val': make_ds(val_indices), 'test': make_ds(test_indices)}
    meta = {'counts': {cls: labels.count(cls) for cls in CLASS_NAMES}, 'total_samples': len(X), 'class_weights': class_weights, 'index_to_class': {i: c for i, c in enumerate(CLASS_NAMES)}}
    return datasets, meta

# %% [markdown]
# ### The CLISA Model Architecture

# %%
# ==============================================================================
# 5. The CLISA Model Architecture
# ==============================================================================

# The custom Attention layer remains the same
class Attention(Layer):
    # ... (Same as before)
    def __init__(self, **kwargs):
        super(Attention, self).__init__(**kwargs)
    def build(self, input_shape):
        self.W = self.add_weight(name="att_weight", shape=(input_shape[-1], 1), initializer="normal")
        self.b = self.add_weight(name="att_bias", shape=(input_shape[1], 1), initializer="zeros")
        super(Attention, self).build(input_shape)
    def call(self, x):
        et = tf.keras.backend.squeeze(tf.keras.backend.tanh(tf.keras.backend.dot(x, self.W) + self.b), axis=-1)
        at = tf.keras.backend.softmax(et)
        at = tf.keras.backend.expand_dims(at, axis=-1)
        output = x * at
        return tf.keras.backend.sum(output, axis=1)

def create_clisa_model(input_shape, num_classes=8, F1=8, D=2, F2=16, dropout_rate=0.25):
    """
    Creates the CLISA model architecture as described in the paper.
    F1: Number of temporal filters.
    D: Depth multiplier for spatial filters.
    F2: Number of pointwise filters.
    """
    C, T = input_shape[0], input_shape[1] # Channels and Timepoints
    
    input_layer = Input(shape=(C, T, 1))

    # --- BLOCK 1: Temporal and Spatial Convolutions ---
    # Temporal Convolution
    x = Conv2D(F1, (1, 64), padding='same', use_bias=False)(input_layer)
    x = BatchNormalization()(x)
    
    # Spatial Convolution (Depthwise)
    x = DepthwiseConv2D((C, 1), use_bias=False, depth_multiplier=D, depthwise_constraint=max_norm(1.))(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation('elu')(x)
    x = AveragePooling2D((1, 4))(x)
    x = Dropout(dropout_rate)(x)

    # --- BLOCK 2: Separable Convolution ---
    # Separable convolution combines depthwise and pointwise convolutions
    x = SeparableConv2D(F2, (1, 16), use_bias=False, padding='same')(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation('elu')(x)
    x = AveragePooling2D((1, 8))(x)
    x = Dropout(dropout_rate)(x)

    # --- Flatten and prepare for LSTM ---
    # Reshape the output to be (batch_size, time_steps, features)
    # The new number of time steps is T // 32 (due to pooling)
    new_time_steps = T // (4 * 8) 
    x = Reshape((new_time_steps, F2))(x)

    # --- Recurrent Layers ---
    x = Bidirectional(LSTM(64, return_sequences=True))(x)
    x = Dropout(0.3)(x)
    
    # --- Output Heads ---
    attention_output = Attention()(x)
    main_path = GlobalAveragePooling1D()(x)
    main_path = concatenate([main_path, attention_output])
    
    binary_head = Dense(32, activation='relu')(main_path)
    binary_head = Dropout(0.5)(binary_head)
    binary_head_output = Dense(1, activation='sigmoid', name='stressed_not_stressed_output')(binary_head)

    multiclass_head = Dense(32, activation='relu')(main_path)
    multiclass_head = Dropout(0.5)(multiclass_head)
    multiclass_head_output = Dense(num_classes, activation='softmax', name='emotion_class_output')(multiclass_head)

    model = Model(
        inputs=input_layer,
        outputs={
            "stressed_not_stressed_output": binary_head_output,
            "emotion_class_output": multiclass_head_output
        }
    )
    return model

# %% [markdown]
# ### Main Execution Block

# %%
# ==============================================================================
# 6. Main Execution Block
# ==============================================================================
if __name__ == '__main__':
    # --- Path and Model Parameters ---
    dataset_path = "/media/kd/New Volume/Github/EEG-Emotion-Detection/dataset"
    
    # Parameters adapted for the CLISA architecture
    INPUT_TIME_STEPS = 512 # The paper uses 1 second of data at 200Hz, we adapt for 128Hz
    INPUT_CHANNELS = len(EEG_CHANNELS)
    INPUT_SHAPE = (INPUT_CHANNELS, INPUT_TIME_STEPS) # (Channels, Time)
    BATCH_SIZE = 8 # This model is efficient, so we can try a slightly larger batch size

    # --- Load Data ---
    print("--- Loading and Preprocessing Dataset ---")
    datasets, meta = load_eeg_dataset(
        data_dir=dataset_path,
        channels=INPUT_CHANNELS,
        time_steps=INPUT_TIME_STEPS,
        batch_size=BATCH_SIZE
    )

    # --- Build and Compile Model ---
    print("\n--- Building CLISA Model ---")
    model = create_clisa_model(INPUT_SHAPE, num_classes=len(CLASS_NAMES))
    optimizer = Adam(learning_rate=1e-3)

    model.compile(
        optimizer=optimizer,
        loss={'stressed_not_stressed_output': 'binary_crossentropy', 'emotion_class_output': 'categorical_crossentropy'},
        loss_weights={'stressed_not_stressed_output': 0.5, 'emotion_class_output': 1.0},
        metrics={'stressed_not_stressed_output': 'accuracy', 'emotion_class_output': 'accuracy'}
    )
    model.summary()

    # --- Define Callbacks ---
    os.makedirs('models', exist_ok=True)
    os.makedirs('logs', exist_ok=True)
    timestamp = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    
    callbacks = [
        ModelCheckpoint(
            filepath=f'models/best_clisa_model_{timestamp}.keras',
            monitor='val_emotion_class_output_accuracy', 
            save_best_only=True, mode='max', verbose=1
        ),
        EarlyStopping(
            monitor='val_emotion_class_output_accuracy', 
            patience=1000, # Give it more patience to learn
            restore_best_weights=True, mode='max', verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_emotion_class_output_accuracy', 
            factor=0.2, patience=8, min_lr=1e-6, mode='max', verbose=1
        ),
        TensorBoard(log_dir=f'logs/fit/{timestamp}', histogram_freq=1)
    ]

    # --- Train the Model ---
    print("\n--- Starting Model Training ---")
    history = model.fit(
        datasets['train'],
        validation_data=datasets['val'],
        epochs=300, # Train for more epochs
        callbacks=callbacks,
        verbose=1
    )

    # --- Final Evaluation and Saving ---
    # ... (This part of the code remains the same as your last working version) ...
# Out:
# --- Loading and Preprocessing Dataset ---
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1758501700.869702  119952 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 797 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# --- Building CLISA Model ---
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 14, 512,   │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 14, 512,   │        512 │ input_layer[0][0] │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 14, 512,   │         32 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 1, 512,    │        224 │ batch_normalizat… │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 512,    │         64 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 1, 512,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 1, 128,    │          0 │ activation[0][0]  │
# │ (AveragePooling2D)  │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1, 128,    │          0 │ average_pooling2… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 1, 128,    │        512 │ dropout[0][0]     │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 128,    │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 1, 128,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 1, 16, 16) │          0 │ activation_1[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1, 16, 16) │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 16, 16)    │          0 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 16, 128)   │     41,472 │ reshape[0][0]     │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 16, 128)   │          0 │ bidirectional[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ dropout_2[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention           │ (None, 128)       │        144 │ dropout_2[0][0]   │
# │ (Attention)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 256)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ attention[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │      8,224 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 32)        │      8,224 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 32)        │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ emotion_class_outp… │ (None, 8)         │        264 │ dropout_4[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stressed_not_stres… │ (None, 1)         │         33 │ dropout_3[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 59,769 (233.47 KB)
#  Trainable params: 59,689 (233.16 KB)
#  Non-trainable params: 80 (320.00 B)
# --- Starting Model Training ---
# Epoch 1/300
# E0000 00:00:1758501704.709671  119952 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/functional_1/dropout_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-09-22 06:11:45.017903: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91300
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - emotion_class_output_accuracy: 0.1130 - emotion_class_output_loss: 2.1057 - loss: 2.4537 - stressed_not_stressed_output_accuracy: 0.5566 - stressed_not_stressed_output_loss: 0.6960
# Epoch 1: val_emotion_class_output_accuracy improved from None to 0.08333, saving model to models/best_clisa_model_20250922-061142.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - emotion_class_output_accuracy: 0.1024 - emotion_class_output_loss: 2.1131 - loss: 2.4496 - stressed_not_stressed_output_accuracy: 0.6386 - stressed_not_stressed_output_loss: 0.6705 - val_emotion_class_output_accuracy: 0.0833 - val_emotion_class_output_loss: 2.0835 - val_loss: 2.4128 - val_stressed_not_stressed_output_accuracy: 0.7500 - val_stressed_not_stressed_output_loss: 0.6653 - learning_rate: 0.0010
# Epoch 2/300
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - emotion_class_output_accuracy: 0.1630 - emotion_class_output_loss: 2.0799 - loss: 2.3920 - stressed_not_stressed_output_accuracy: 0.7516 - stressed_not_stressed_output_loss: 0.6242
# Epoch 2: val_emotion_class_output_accuracy improved from 0.08333 to 0.11111, saving model to models/best_clisa_model_20250922-061142.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - emotion_class_output_accuracy: 0.1566 - emotion_class_output_loss: 2.0698 - loss: 2.3747 - stressed_not_stressed_output_accuracy: 0.7470 - stressed_not_stressed_output_loss: 0.6081 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.0747 - val_loss: 2.3948 - val_stressed_not_stressed_output_accuracy: 0.7500 - val_stressed_not_stressed_output_loss: 0.6384 - learning_rate: 0.0010
# Epoch 3/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - emotion_class_output_accuracy: 0.1780 - emotion_class_output_loss: 2.0846 - loss: 2.3690 - stressed_not_stressed_output_accuracy: 0.7730 - stressed_not_stressed_output_loss: 0.5691
# Epoch 3: val_emotion_class_output_accuracy improved from 0.11111 to 0.16667, saving model to models/best_clisa_model_20250922-061142.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - emotion_class_output_accuracy: 0.1807 - emotion_class_output_loss: 2.0698 - loss: 2.3637 - stressed_not_stressed_output_accuracy: 0.7410 - stressed_not_stressed_output_loss: 0.5914 - val_emotion_class_output_accuracy: 0.1667 - val_emotion_class_output_loss: 2.0674 - val_loss: 2.3662 - val_stressed_not_stressed_output_accuracy: 0.7500 - val_stressed_not_stressed_output_loss: 0.5918 - learning_rate: 0.0010
# Epoch 4/300
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - emotion_class_output_accuracy: 0.2088 - emotion_class_output_loss: 2.0518 - loss: 2.3596 - stressed_not_stressed_output_accuracy: 0.7067 - stressed_not_stressed_output_loss: 0.6156
# Epoch 4: val_emotion_class_output_accuracy did not improve from 0.16667
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - emotion_class_output_accuracy: 0.2169 - emotion_class_output_loss: 2.0529 - loss: 2.3498 - stressed_not_stressed_output_accuracy: 0.7410 - stressed_not_stressed_output_loss: 0.5907 - val_emotion_class_output_accuracy: 0.1667 - val_emotion_class_output_loss: 2
- val_emotion_class_output_accuracy: 0.1389 - val_emotion_class_output_loss: 2.2613 - val_loss: 2.6171 - val_stressed_not_stressed_output_accuracy: 0.6667 - val_stressed_not_stressed_output_loss: 0.6740 - learning_rate: 2.0000e-04
# Epoch 24/300
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - emotion_class_output_accuracy: 0.3747 - emotion_class_output_loss: 1.6815 - loss: 1.8478 - stressed_not_stressed_output_accuracy: 0.8641 - stressed_not_stressed_output_loss: 0.3326
# Epoch 24: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - emotion_class_output_accuracy: 0.3554 - emotion_class_output_loss: 1.7374 - loss: 1.9149 - stressed_not_stressed_output_accuracy: 0.8614 - stressed_not_stressed_output_loss: 0.3553 - val_emotion_class_output_accuracy: 0.1389 - val_emotion_class_output_loss: 2.2826 - val_loss: 2.6209 - val_stressed_not_stressed_output_accuracy: 0.6667 - val_stressed_not_stressed_output_loss: 0.6897 - learning_rate: 4.0000e-05
# Epoch 25/300
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - emotion_class_output_accuracy: 0.3601 - emotion_class_output_loss: 1.7282 - loss: 1.9103 - stressed_not_stressed_output_accuracy: 0.8491 - stressed_not_stressed_output_loss: 0.3641
# Epoch 25: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - emotion_class_output_accuracy: 0.3434 - emotion_class_output_loss: 1.6976 - loss: 1.8816 - stressed_not_stressed_output_accuracy: 0.8554 - stressed_not_stressed_output_loss: 0.3648 - val_emotion_class_output_accuracy: 0.1389 - val_emotion_class_output_loss: 2.2885 - val_loss: 2.6184 - val_stressed_not_stressed_output_accuracy: 0.6944 - val_stressed_not_stressed_output_loss: 0.7068 - learning_rate: 4.0000e-05
# Epoch 26/300
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - emotion_class_output_accuracy: 0.3688 - emotion_class_output_loss: 1.6833 - loss: 1.9281 - stressed_not_stressed_output_accuracy: 0.7681 - stressed_not_stressed_output_loss: 0.4896
# Epoch 26: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - emotion_class_output_accuracy: 0.3253 - emotion_class_output_loss: 1.7464 - loss: 1.9254 - stressed_not_stressed_output_accuracy: 0.8614 - stressed_not_stressed_output_loss: 0.3602 - val_emotion_class_output_accuracy: 0.1389 - val_emotion_class_output_loss: 2.2601 - val_loss: 2.6197 - val_stressed_not_stressed_output_accuracy: 0.6944 - val_stressed_not_stressed_output_loss: 0.6258 - learning_rate: 4.0000e-05
# Epoch 27/300
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - emotion_class_output_accuracy: 0.4284 - emotion_class_output_loss: 1.6857 - loss: 1.8709 - stressed_not_stressed_output_accuracy: 0.8615 - stressed_not_stressed_output_loss: 0.3702
# Epoch 27: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - emotion_class_output_accuracy: 0.3614 - emotion_class_output_loss: 1.7283 - loss: 1.9210 - stressed_not_stressed_output_accuracy: 0.8434 - stressed_not_stressed_output_loss: 0.3822 - val_emotion_class_output_accuracy: 0.1667 - val_emotion_class_output_loss: 2.2952 - val_loss: 2.6202 - val_stressed_not_stressed_output_accuracy: 0.6944 - val_stressed_not_stressed_output_loss: 0.6499 - learning_rate: 4.0000e-05
# Epoch 28/300
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - emotion_class_output_accuracy: 0.4552 - emotion_class_output_loss: 1.7024 - loss: 1.8816 - stressed_not_stressed_output_accuracy: 0.8230 - stressed_not_stressed_output_loss: 0.3585
# Epoch 28: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - emotion_class_output_accuracy: 0.3916 - emotion_class_output_loss: 1.7392 - loss: 1.9149 - stressed_not_stressed_output_accuracy: 0.8313 - stressed_not_stressed_output_loss: 0.3495 - val_emotion_class_output_accuracy: 0.1389 - val_emotion_class_output_loss: 2.3248 - val_loss: 2.6205 - val_stressed_not_stressed_output_accuracy: 0.6944 - val_stressed_not_stressed_output_loss: 0.6297 - learning_rate: 4.0000e-05
# Epoch 29/300
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - emotion_class_output_accuracy: 0.3719 - emotion_class_output_loss: 1.6653 - loss: 1.8090 - stressed_not_stressed_output_accuracy: 0.9007 - stressed_not_stressed_output_loss: 0.2874
# Epoch 29: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - emotion_class_output_accuracy: 0.3434 - emotion_class_output_loss: 1.7137 - loss: 1.8788 - stressed_not_stressed_output_accuracy: 0.8554 - stressed_not_stressed_output_loss: 0.3277 - val_emotion_class_output_accuracy: 0.1389 - val_emotion_class_output_loss: 2.3155 - val_loss: 2.6261 - val_stressed_not_stressed_output_accuracy: 0.6944 - val_stressed_not_stressed_output_loss: 0.6915 - learning_rate: 4.0000e-05
# Epoch 30/300
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - emotion_class_output_accuracy: 0.4232 - emotion_class_output_loss: 1.6456 - loss: 1.8195 - stressed_not_stressed_output_accuracy: 0.8578 - stressed_not_stressed_output_loss: 0.3477
# Epoch 30: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - emotion_class_output_accuracy: 0.3554 - emotion_class_output_loss: 1.7079 - loss: 1.8783 - stressed_not_stressed_output_accuracy: 0.8675 - stressed_not_stressed_output_loss: 0.3505 - val_emotion_class_output_accuracy: 0.1389 - val_emotion_class_output_loss: 2.3061 - val_loss: 2.6319 - val_stressed_not_stressed_output_accuracy: 0.6944 - val_stressed_not_stressed_output_loss: 0.6283 - learning_rate: 4.0000e-05
# Epoch 31/300
# 16/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - emotion_class_output_accuracy: 0.3193 - emotion_class_output_loss: 1.7425 - loss: 1.9005 - stressed_not_stressed_output_accuracy: 0.8499 - stressed_not_stressed_output_loss: 0.3161
# Epoch 31: val_emotion_class_output_accuracy did not improve from 0.22222
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - emotion_class_output_accuracy: 0.
- val_emotion_class_output_accuracy: 0.1667 - val_emotion_class_output_loss: 2.2768 - val_loss: 2.6314 - val_stressed_not_stressed_output_accuracy: 0.6944 - val_stressed_not_stressed_output_loss: 0.6891 - learning_rate: 1.6000e-06
# Epoch 47/300
# 16/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - emotion_class_output_accuracy: 0.3300 - emotion_class_output_loss: 1.8081 - loss: 2.0079 - stressed_not_stressed_output_accuracy: 0.8247 - stressed_not_stressed_output_loss: 0.3996
# Epoch 47: val_emotion_class_output_accuracy did not improve from 0.22222
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-06.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - emotion_class_output_accuracy: 0.3313 - emotion_class_output_loss: 1.7651 - loss: 1.9516 - stressed_not_stressed_output_accuracy: 0.8494 - stressed_not_stressed_output_loss: 0.3604 - val_emotion_class_output_accuracy: 0.1667 - val_emotion_class_output_loss: 2.3049 - val_loss: 2.6330 - val_stressed_not_stressed_output_accuracy: 0.6944 - val_stressed_not_stressed_output_loss: 0.6700 - learning_rate: 1.6000e-06
# Epoch 48/300
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - emotion_class_output_accuracy: 0.5126 - emotion_class_output_loss: 1.6017 - loss: 1.7628 - stressed_not_stressed_output_accuracy: 0.8296 - stressed_not_stressed_output_loss: 0.3221
# Epoch 48: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - emotion_class_output_accuracy: 0.4518 - emotion_class_output_loss: 1.6672 - loss: 1.8456 - stressed_not_stressed_output_accuracy: 0.8072 - stressed_not_stressed_output_loss: 0.3577 - val_emotion_class_output_accuracy: 0.1667 - val_emotion_class_output_loss: 2.2861 - val_loss: 2.6337 - val_stressed_not_stressed_output_accuracy: 0.6944 - val_stressed_not_stressed_output_loss: 0.6764 - learning_rate: 1.0000e-06
# Epoch 49/300
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - emotion_class_output_accuracy: 0.2736 - emotion_class_output_loss: 1.8162 - loss: 1.9722 - stressed_not_stressed_output_accuracy: 0.8809 - stressed_not_stressed_output_loss: 0.3120
# Epoch 49: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - emotion_class_output_accuracy: 0.3554 - emotion_class_output_loss: 1.7333 - loss: 1.8821 - stressed_not_stressed_output_accuracy: 0.8855 - stressed_not_stressed_output_loss: 0.3059 - val_emotion_class_output_accuracy: 0.1389 - val_emotion_class_output_loss: 2.3078 - val_loss: 2.6334 - val_stressed_not_stressed_output_accuracy: 0.6944 - val_stressed_not_stressed_output_loss: 0.6813 - learning_rate: 1.0000e-06
# Epoch 50/300
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - emotion_class_output_accuracy: 0.3408 - emotion_class_output_loss: 1.7619 - loss: 1.9490 - stressed_not_stressed_output_accuracy: 0.8335 - stressed_not_stressed_output_loss: 0.3741
# Epoch 50: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - emotion_class_output_accuracy: 0.3434 - emotion_class_output_loss: 1.7564 - loss: 1.9232 - stressed_not_stressed_output_accuracy: 0.8675 - stressed_not_stressed_output_loss: 0.3313 - val_emotion_class_output_accuracy: 0.1667 - val_emotion_class_output_loss: 2.2425 - val_loss: 2.6336 - val_stressed_not_stressed_output_accuracy: 0.6944 - val_stressed_not_stressed_output_loss: 0.6301 - learning_rate: 1.0000e-06
# Epoch 51/300
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - emotion_class_output_accuracy: 0.3543 - emotion_class_output_loss: 1.7133 - loss: 1.8800 - stressed_not_stressed_output_accuracy: 0.8610 - stressed_not_stressed_output_loss: 0.3334
# Epoch 51: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - emotion_class_output_accuracy: 0.3494 - emotion_class_output_loss: 1.7263 - loss: 1.8933 - stressed_not_stressed_output_accuracy: 0.8614 - stressed_not_stressed_output_loss: 0.3336 - val_emotion_class_output_accuracy: 0.1667 - val_emotion_class_output_loss: 2.2870 - val_loss: 2.6334 - val_stressed_not_stressed_output_accuracy: 0.6944 - val_stressed_not_stressed_output_loss: 0.6328 - learning_rate: 1.0000e-06
# Epoch 52/300
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - emotion_class_output_accuracy: 0.4161 - emotion_class_output_loss: 1.7226 - loss: 1.8846 - stressed_not_stressed_output_accuracy: 0.8747 - stressed_not_stressed_output_loss: 0.3239
# Epoch 52: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - emotion_class_output_accuracy: 0.4036 - emotion_class_output_loss: 1.7101 - loss: 1.8747 - stressed_not_stressed_output_accuracy: 0.8614 - stressed_not_stressed_output_loss: 0.3289 - val_emotion_class_output_accuracy: 0.1667 - val_emotion_class_output_loss: 2.2632 - val_loss: 2.6330 - val_stressed_not_stressed_output_accuracy: 0.6944 - val_stressed_not_stressed_output_loss: 0.6447 - learning_rate: 1.0000e-06
# Epoch 53/300
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - emotion_class_output_accuracy: 0.3119 - emotion_class_output_loss: 1.8006 - loss: 1.9630 - stressed_not_stressed_output_accuracy: 0.8698 - stressed_not_stressed_output_loss: 0.3249
# Epoch 53: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - emotion_class_output_accuracy: 0.3193 - emotion_class_output_loss: 1.8060 - loss: 1.9619 - stressed_not_stressed_output_accuracy: 0.8675 - stressed_not_stressed_output_loss: 0.3187 - val_emotion_class_output_accuracy: 0.1389 - val_emotion_class_output_loss: 2.2631 - val_loss: 2.6338 - val_stressed_not_stressed_output_accuracy: 0.6944 - val_stressed_not_stressed_output_loss: 0.6154 - learning_rate: 1.0000e-06
# Epoch 54/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - emotion_class_output_accuracy: 0.3496 - emotion_class_output_loss: 1.7105 - loss: 1.8645 - stressed_not_stressed_output_accuracy: 0.8992 - stressed_not_stressed_output_loss: 0.3080
# Epoch 54: val_emotion_class_output_accuracy did not improve from 0.22222
# ...
# Epoch 280: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - emotion_class_output_accuracy: 0.3855 - emotion_class_output_loss: 1.6871 - loss: 1.8497 - stressed_not_stressed_output_accuracy: 0.8554 - stressed_not_stressed_output_loss: 0.3177 - val_emotion_class_output_accuracy: 0.0833 - val_emotion_class_output_loss: 2.2713 - val_loss: 2.6460 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.6191 - learning_rate: 1.0000e-06
# Epoch 281/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - emotion_class_output_accuracy: 0.2538 - emotion_class_output_loss: 1.8847 - loss: 2.0393 - stressed_not_stressed_output_accuracy: 0.8561 - stressed_not_stressed_output_loss: 0.3093
# Epoch 281: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - emotion_class_output_accuracy: 0.3313 - emotion_class_output_loss: 1.7805 - loss: 1.9329 - stressed_not_stressed_output_accuracy: 0.8554 - stressed_not_stressed_output_loss: 0.3072 - val_emotion_class_output_accuracy: 0.0833 - val_emotion_class_output_loss: 2.3380 - val_loss: 2.6455 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.6848 - learning_rate: 1.0000e-06
# Epoch 282/300
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - emotion_class_output_accuracy: 0.2881 - emotion_class_output_loss: 1.8040 - loss: 1.9904 - stressed_not_stressed_output_accuracy: 0.8369 - stressed_not_stressed_output_loss: 0.3728
# Epoch 282: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - emotion_class_output_accuracy: 0.2952 - emotion_class_output_loss: 1.7648 - loss: 1.9504 - stressed_not_stressed_output_accuracy: 0.8494 - stressed_not_stressed_output_loss: 0.3699 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.2594 - val_loss: 2.6442 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.6404 - learning_rate: 1.0000e-06
# Epoch 283/300
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - emotion_class_output_accuracy: 0.3198 - emotion_class_output_loss: 1.7304 - loss: 1.9601 - stressed_not_stressed_output_accuracy: 0.8535 - stressed_not_stressed_output_loss: 0.4593
# Epoch 283: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - emotion_class_output_accuracy: 0.3253 - emotion_class_output_loss: 1.7297 - loss: 1.9198 - stressed_not_stressed_output_accuracy: 0.8675 - stressed_not_stressed_output_loss: 0.3833 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.3017 - val_loss: 2.6448 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.6513 - learning_rate: 1.0000e-06
# Epoch 284/300
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - emotion_class_output_accuracy: 0.3134 - emotion_class_output_loss: 1.7482 - loss: 1.8930 - stressed_not_stressed_output_accuracy: 0.8833 - stressed_not_stressed_output_loss: 0.2898
# Epoch 284: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - emotion_class_output_accuracy: 0.3675 - emotion_class_output_loss: 1.7045 - loss: 1.8600 - stressed_not_stressed_output_accuracy: 0.8916 - stressed_not_stressed_output_loss: 0.3038 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.2939 - val_loss: 2.6443 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.6359 - learning_rate: 1.0000e-06
# Epoch 285/300
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - emotion_class_output_accuracy: 0.3985 - emotion_class_output_loss: 1.6240 - loss: 1.7820 - stressed_not_stressed_output_accuracy: 0.8724 - stressed_not_stressed_output_loss: 0.3159
# Epoch 285: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - emotion_class_output_accuracy: 0.3554 - emotion_class_output_loss: 1.6835 - loss: 1.8406 - stressed_not_stressed_output_accuracy: 0.8916 - stressed_not_stressed_output_loss: 0.3145 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.2748 - val_loss: 2.6455 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.6181 - learning_rate: 1.0000e-06
# Epoch 286/300
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - emotion_class_output_accuracy: 0.3064 - emotion_class_output_loss: 1.7308 - loss: 1.9036 - stressed_not_stressed_output_accuracy: 0.8170 - stressed_not_stressed_output_loss: 0.3457
# Epoch 286: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - emotion_class_output_accuracy: 0.3795 - emotion_class_output_loss: 1.6942 - loss: 1.8570 - stressed_not_stressed_output_accuracy: 0.8434 - stressed_not_stressed_output_loss: 0.3324 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.2600 - val_loss: 2.6458 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.7151 - learning_rate: 1.0000e-06
# Epoch 287/300
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - emotion_class_output_accuracy: 0.3529 - emotion_class_output_loss: 1.7287 - loss: 1.9225 - stressed_not_stressed_output_accuracy: 0.8182 - stressed_not_stressed_output_loss: 0.3875
# Epoch 287: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - emotion_class_output_accuracy: 0.3795 - emotion_class_output_loss: 1.7213 - loss: 1.9133 - stressed_not_stressed_output_accuracy: 0.8193 - stressed_not_stressed_output_loss: 0.3930 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.3807 - val_loss: 2.6465 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.7056 - learning_rate: 1.0000e-06
# Epoch 288/300
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - emotion_class_output_accuracy: 0.4162 - emotion_class_output_loss: 1.5940 - loss: 1.7578 - stressed_not_stressed_output_accuracy: 0.8671 - stressed_not_stressed_output_loss: 0.3276
# Epoch 288: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - emotion_class_output_accuracy: 0.3614 - emotion_class_output_loss: 1.7022 - loss: 1.8691 - stressed_not_stressed_output_accuracy: 0.8614 - stressed_not_stressed_output_loss: 0.3263 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.2658 - val_loss: 2.6464 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.7136 - learning_rate: 1.0000e-06
# Epoch 289/300
# 16/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - emotion_class_output_accuracy: 0.4392 - emotion_class_output_loss: 1.6584 - loss: 1.7867 - stressed_not_stressed_output_accuracy: 0.9153 - stressed_not_stressed_output_loss: 0.2566
# Epoch 289: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - emotion_class_output_accuracy: 0.4036 - emotion_class_output_loss: 1.6732 - loss: 1.8421 - stressed_not_stressed_output_accuracy: 0.8554 - stressed_not_stressed_output_loss: 0.3398 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.3211 - val_loss: 2.6470 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.7060 - learning_rate: 1.0000e-06
# Epoch 290/300
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - emotion_class_output_accuracy: 0.4046 - emotion_class_output_loss: 1.7494 - loss: 1.9019 - stressed_not_stressed_output_accuracy: 0.8928 - stressed_not_stressed_output_loss: 0.3049
# Epoch 290: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - emotion_class_output_accuracy: 0.3675 - emotion_class_output_loss: 1.7424 - loss: 1.8902 - stressed_not_stressed_output_accuracy: 0.8855 - stressed_not_stressed_output_loss: 0.2852 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.3287 - val_loss: 2.6467 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.6339 - learning_rate: 1.0000e-06
# Epoch 291/300
# 16/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - emotion_class_output_accuracy: 0.4044 - emotion_class_output_loss: 1.6063 - loss: 1.7723 - stressed_not_stressed_output_accuracy: 0.8505 - stressed_not_stressed_output_loss: 0.3320
# Epoch 291: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - emotion_class_output_accuracy: 0.3554 - emotion_class_output_loss: 1.6543 - loss: 1.8165 - stressed_not_stressed_output_accuracy: 0.8675 - stressed_not_stressed_output_loss: 0.3121 - val_emotion_class_output_accuracy: 0.0833 - val_emotion_class_output_loss: 2.3049 - val_loss: 2.6463 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.6640 - learning_rate: 1.0000e-06
# Epoch 292/300
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - emotion_class_output_accuracy: 0.3561 - emotion_class_output_loss: 1.7326 - loss: 1.9150 - stressed_not_stressed_output_accuracy: 0.7943 - stressed_not_stressed_output_loss: 0.3648
# Epoch 292: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - emotion_class_output_accuracy: 0.3855 - emotion_class_output_loss: 1.6789 - loss: 1.8616 - stressed_not_stressed_output_accuracy: 0.8253 - stressed_not_stressed_output_loss: 0.3517 - val_emotion_class_output_accuracy: 0.1389 - val_emotion_class_output_loss: 2.3066 - val_loss: 2.6455 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.6854 - learning_rate: 1.0000e-06
# Epoch 293/300
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - emotion_class_output_accuracy: 0.2770 - emotion_class_output_loss: 1.8186 - loss: 1.9721 - stressed_not_stressed_output_accuracy: 0.8539 - stressed_not_stressed_output_loss: 0.3070
# Epoch 293: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - emotion_class_output_accuracy: 0.3494 - emotion_class_output_loss: 1.7080 - loss: 1.8656 - stressed_not_stressed_output_accuracy: 0.8675 - stressed_not_stressed_output_loss: 0.3187 - val_emotion_class_output_accuracy: 0.1389 - val_emotion_class_output_loss: 2.2988 - val_loss: 2.6454 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.6399 - learning_rate: 1.0000e-06
# Epoch 294/300
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - emotion_class_output_accuracy: 0.3707 - emotion_class_output_loss: 1.6875 - loss: 1.8774 - stressed_not_stressed_output_accuracy: 0.8511 - stressed_not_stressed_output_loss: 0.3798
# Epoch 294: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - emotion_class_output_accuracy: 0.3916 - emotion_class_output_loss: 1.6590 - loss: 1.8283 - stressed_not_stressed_output_accuracy: 0.8554 - stressed_not_stressed_output_loss: 0.3385 - val_emotion_class_output_accuracy: 0.1389 - val_emotion_class_output_loss: 2.3584 - val_loss: 2.6456 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.8016 - learning_rate: 1.0000e-06
# Epoch 295/300
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - emotion_class_output_accuracy: 0.3556 - emotion_class_output_loss: 1.7716 - loss: 1.9628 - stressed_not_stressed_output_accuracy: 0.8311 - stressed_not_stressed_output_loss: 0.3823
# Epoch 295: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - emotion_class_output_accuracy: 0.3133 - emotion_class_output_loss: 1.8113 - loss: 1.9859 - stressed_not_stressed_output_accuracy: 0.8434 - stressed_not_stressed_output_loss: 0.3545 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.2754 - val_loss: 2.6457 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.6332 - learning_rate: 1.0000e-06
# Epoch 296/300
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - emotion_class_output_accuracy: 0.3875 - emotion_class_output_loss: 1.7508 - loss: 1.9398 - stressed_not_stressed_output_accuracy: 0.8644 - stressed_not_stressed_output_loss: 0.3780
# Epoch 296: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - emotion_class_output_accuracy: 0.3735 - emotion_class_output_loss: 1.7094 - loss: 1.8821 - stressed_not_stressed_output_accuracy: 0.8614 - stressed_not_stressed_output_loss: 0.3483 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.2923 - val_loss: 2.6468 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.7124 - learning_rate: 1.0000e-06
# Epoch 297/300
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - emotion_class_output_accuracy: 0.4081 - emotion_class_output_loss: 1.7673 - loss: 1.9274 - stressed_not_stressed_output_accuracy: 0.8819 - stressed_not_stressed_output_loss: 0.3202
# Epoch 297: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - emotion_class_output_accuracy: 0.3675 - emotion_class_output_loss: 1.7776 - loss: 1.9523 - stressed_not_stressed_output_accuracy: 0.8675 - stressed_not_stressed_output_loss: 0.3655 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.3193 - val_loss: 2.6473 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.7221 - learning_rate: 1.0000e-06
# Epoch 298/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - emotion_class_output_accuracy: 0.2962 - emotion_class_output_loss: 1.7372 - loss: 1.8903 - stressed_not_stressed_output_accuracy: 0.8743 - stressed_not_stressed_output_loss: 0.3057
# Epoch 298: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - emotion_class_output_accuracy: 0.3313 - emotion_class_output_loss: 1.7361 - loss: 1.9086 - stressed_not_stressed_output_accuracy: 0.8494 - stressed_not_stressed_output_loss: 0.3353 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.3340 - val_loss: 2.6466 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.7255 - learning_rate: 1.0000e-06
# Epoch 299/300
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - emotion_class_output_accuracy: 0.3203 - emotion_class_output_loss: 1.7422 - loss: 1.8862 - stressed_not_stressed_output_accuracy: 0.9302 - stressed_not_stressed_output_loss: 0.2879
# Epoch 299: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - emotion_class_output_accuracy: 0.3072 - emotion_class_output_loss: 1.7747 - loss: 1.9277 - stressed_not_stressed_output_accuracy: 0.8855 - stressed_not_stressed_output_loss: 0.3110 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.2944 - val_loss: 2.6478 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.7484 - learning_rate: 1.0000e-06
# Epoch 300/300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - emotion_class_output_accuracy: 0.4532 - emotion_class_output_loss: 1.6419 - loss: 1.8038 - stressed_not_stressed_output_accuracy: 0.8910 - stressed_not_stressed_output_loss: 0.3237
# Epoch 300: val_emotion_class_output_accuracy did not improve from 0.22222
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - emotion_class_output_accuracy: 0.4157 - emotion_class_output_loss: 1.6803 - loss: 1.8566 - stressed_not_stressed_output_accuracy: 0.8313 - stressed_not_stressed_output_loss: 0.3520 - val_emotion_class_output_accuracy: 0.1111 - val_emotion_class_output_loss: 2.2864 - val_loss: 2.6470 - val_stressed_not_stressed_output_accuracy: 0.7222 - val_stressed_not_stressed_output_loss: 0.7235 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 7.
